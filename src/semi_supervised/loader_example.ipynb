# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pwd #you should be in src/semi_supervised
# Out:
# /Users/mohammedsbaihi/Code/weld-quality/src/semi_supervised

# %%
import sys
from pathlib import Path

# Add 'src' directory (parent of 'semi_supervised') to sys.path
sys.path.append(str(Path().resolve().parents[0]))

from semi_supervised.loader import load_data, load_data_with_token, split_train_val_test, TARGET_COLS
print(TARGET_COLS)
# Out:
# ['yield_strength_MPa', 'uts_MPa', 'elongation_pct', 'reduction_area_pct', 'charpy_temp_C', 'charpy_toughness_J']

# %%
TARGET = TARGET_COLS[0]
labeled_data = load_data(TARGET, split="labeled")
unlabeled_data = load_data(TARGET, split="unlabeled")
(X_train, y_train), (X_val, y_val), (X_test, y_test) = split_train_val_test(labeled_data, unlabeled_data, TARGET)
# Out:
# Loading dataset from Hugging Face Hub...
# Imputing missing values...
# Dropping columns with >80.0% missing values (excluding target 'yield_strength_MPa'): ['cobalt_wt_pct', 'tungsten_wt_pct', 'boron_ppm', 'tin_ppm', 'arsenic_ppm', 'antimony_ppm', 'primary_ferrite_pct', 'ferrite_second_phase_pct', 'acicular_ferrite_pct', 'martensite_pct', 'ferrite_carbide_pct']
# Data loading and imputation completed.
# Loading dataset from Hugging Face Hub...
# Imputing missing values...
# Dropping columns with >80.0% missing values (excluding target 'yield_strength_MPa'): ['cobalt_wt_pct', 'tungsten_wt_pct', 'boron_ppm', 'niobium_ppm', 'tin_ppm', 'arsenic_ppm', 'antimony_ppm', 'primary_ferrite_pct', 'ferrite_second_phase_pct', 'acicular_ferrite_pct', 'martensite_pct', 'ferrite_carbide_pct']
# Data loading and imputation completed.
# Splitting data into train, validation, and test sets...
# ...

# %%
unlabeled_data = load_data(TARGET, split="unlabeled")
# Out:
# Loading dataset from Hugging Face Hub...
# Imputing missing values...
# Dropping columns with >80.0% missing values (excluding target 'yield_strength_MPa'): ['cobalt_wt_pct', 'tungsten_wt_pct', 'boron_ppm', 'niobium_ppm', 'tin_ppm', 'arsenic_ppm', 'antimony_ppm', 'primary_ferrite_pct', 'ferrite_second_phase_pct', 'acicular_ferrite_pct', 'martensite_pct', 'ferrite_carbide_pct']
# Columns after cleaning: Index(['carbon_wt_pct', 'silicon_wt_pct', 'manganese_wt_pct', 'sulfur_wt_pct',
#        'phosphorus_wt_pct', 'nickel_wt_pct', 'chromium_wt_pct',
#        'molybdenum_wt_pct', 'vanadium_wt_pct', 'copper_wt_pct', 'oxygen_ppm',
#        'titanium_ppm', 'nitrogen_ppm', 'aluminium_ppm', 'current_A',
#        'voltage_V', 'heat_input_kJmm', 'interpass_temp_C', 'pwht_temp_C',
#        'pwht_time_h', 'yield_strength_MPa', 'weld_type_FCA', 'weld_type_GMAA',
#        'weld_type_GTAA', 'weld_type_MMA', 'weld_type_NGGMA', 'weld_type_NGSAW',
# ...
