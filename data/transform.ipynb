# %% [markdown]
# # Data Transformation
# - None values handling
# - One hot encoding (if any)
# - Scaling (if any)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data

df = pd.read_parquet("hf://datasets/MoSBAIHI/weld-quality-dataset/data/train-00000-of-00001.parquet")

# %%
df = df.replace('N', None)

# %%
def plot_histogram(column_name):
    data = df[column_name].dropna()
    # Convert to numeric if possible (handles object columns with numbers as strings)
    data = pd.to_numeric(data, errors='coerce').dropna()
    plt.figure(figsize=(4, 3))
    sns.histplot(data, kde=True)
    plt.title(f'Histogram of {column_name}')
    plt.xlabel(column_name)
    plt.ylabel('Frequency')
    plt.show()

# %%
plot_histogram("Silicon concentration / (weight%)")
plot_histogram("Manganese concentration / (weight%)")
plot_histogram("Phosphorus concentration / (weight%)")
plot_histogram("Sulphur concentration / (weight%)")
plot_histogram("Carbon concentration / (weight%)")

# %%
columns_with_none = [col for col in df.columns if df[col].isnull().any()]
print(len(columns_with_none))
# Out:
# 37

# %%
df.head()
# Out:
#    Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# 0                             0.037                               0.30
# 1                             0.037                               0.30
# 2                             0.037                               0.30
# 3                             0.037                               0.31
# 4                             0.037                               0.31
#
#    Manganese concentration / (weight%) Sulphur concentration / (weight%)  \
# 0                                 0.65                             0.008
# 1                                 0.65                             0.008
# 2                                 0.65                             0.008
# 3                                 1.03                             0.007
# 4                                 1.03                             0.007
#
#   Phosphorus concentration / (weight%) Nickel concentration / (weight%)  \
# ...
